# %% [markdown]
# ## This notebook is the implementation of the ALEXNET paper

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader

# %%
class alex(nn.Module):
    def __init__(self, input, classes):
        super(alex, self).__init__()
        fc1 = nn.Linear(1, 64)
        fc2 = nn.Linear(64,10)
        conv1 = nn.Conv2d(227, 55, 11, 4)


    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
print('testing auto save for github')
# Out:
# testing auto save for github
