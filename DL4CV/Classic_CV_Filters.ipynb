# %% [markdown]
# ## Classic CV Filters with torch and CV

# %%
import cv2
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# - Here i have avoided the border pixels in the range loop as this is without any padding

# %%
from torch import from_numpy
from cv2 import COLOR_BGR2RGB
## Set your image
b = cv2.imread('/home/aryan/code/Computer_vision/Media/img3.webp')
## Set your kernel
gaus = torch.tensor([
    [1, 2, 1],
    [2, 4, 2],
    [1, 2, 1]
], dtype=torch.float32) / 16

# %%
img = cv2.cvtColor(b ,cv2.COLOR_BGR2GRAY)       
img = cv2.resize(img, (100,100))
img = torch.tensor(img, dtype=torch.float32)
result = torch.zeros_like(img)


def OPS(x, y, kernel, result, img):
    for i in range(1, x-1):
        for j in range(1, y-1):
            region = img[i-1:i+2, j-1:j+2]
            new = (region @ kernel).sum()
            result[i,j] = new
    return result

# %%
x, y = img.shape

c = OPS(x,y, gaus, result, img)

plt.figure(figsize=(12,10))

plt.subplot(1,2,1)
plt.imshow(img, cmap='grey')
plt.title('Original')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(c, cmap='grey')
plt.title('After Gauss')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(99.5), np.float64(99.5), np.float64(-0.5))

# %% [markdown]
# ## Applying Sobel filter on the Image

# %%
img = torch.tensor(img, dtype=torch.float32)
result = torch.zeros_like(img)


def OPS(x, y, kernel, result, img):
    for i in range(1, x-1):
        for j in range(1, y-1):
            region = img[i-1:i+2, j-1:j+2]
            new = (region @ kernel).sum()
            result[i,j] = new
    return result
# Out:
# /tmp/ipykernel_25336/1611343469.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   img = torch.tensor(img, dtype=torch.float32)

# %%
x, y = img.shape

c = OPS(x,y, gaus, result, img)

plt.figure(figsize=(12,10))

plt.subplot(1,2,1)
plt.imshow(img, cmap='grey')
plt.title('Original')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(c, cmap='grey')
plt.title('After Gauss')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(99.5), np.float64(99.5), np.float64(-0.5))
