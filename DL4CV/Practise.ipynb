# %%
import cv2
import torch
import matplotlib.pyplot as plt

# %%
b = cv2.imread('/home/aryan/code/Computer_vision/Media/img1.jpg')
gaus = torch.tensor([[1,2,1], [2,4,2], [1,2,1]])

b = torch.from_numpy(b)
torch.flatten(b)
# Out:
# tensor([255, 254, 253,  ...,  53, 159, 112], dtype=torch.uint8)
