# %% [markdown]
# ## Lab 1 for Building simple NN using Pytorch

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
distance = torch.tensor([[1.0], [2.0], [3.0], [4.0]], dtype=torch.float32)
times = torch.tensor([[6.96], [12.11], [16.77], [22.21]], dtype=torch.float32)

# %% [markdown]
# - Sequential holds the network could be multilayer netowork as well

# %%
model = nn.Sequential(nn.Linear(1,1))

# %% [markdown]
# - Here parameters are Weights and bias that optimizer needs to improve from the model

# %%
loss_func = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# - ```optimizer.zero_grad()```: Clears gradients from the previous round. Without this, PyTorch would accumulate adjustments, which could break the learning process.
#
# - `outputs = model(distances)`: Performs the "forward pass", where the model makes predictions based on the input distances.
#
# - `loss = loss_function(outputs, times)`: Calculates how wrong the predicted outputs are by comparing them to the actual delivery times.
#
# - `loss.backward()`: The "backward pass" (backpropagation) is performed, which calculates exactly how to adjust the weight and bias to reduce the error.
#
# - `optimizer.step()`: Updates the model's parameters using those calculated adjustments.

# %%
for epoch in range(500):
    optimizer.zero_grad()
    output = model(distance)
    loss = loss_func(output, times)
    loss.backward()
    optimizer.step()

    if (epoch+1) % 50 == 0:
        print(f"Epoch: {epoch+1}: Loss = {loss.item()}")
# Out:
# Epoch: 50: Loss = 0.06683699041604996
# Epoch: 100: Loss = 0.05610371008515358
# Epoch: 150: Loss = 0.04815403372049332
# Epoch: 200: Loss = 0.04226367175579071
# Epoch: 250: Loss = 0.03789942339062691
# Epoch: 300: Loss = 0.03466598689556122
# Epoch: 350: Loss = 0.03226989135146141
# Epoch: 400: Loss = 0.03049463964998722
# Epoch: 450: Loss = 0.029179520905017853
# Epoch: 500: Loss = 0.028204692527651787
